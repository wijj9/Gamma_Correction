# %%
import subprocess
import pandas as pd
import matplotlib.pyplot as plt

# %%
reps = 100
gamma = 1
version = 0

path = "/home/andreas/Documents/Uni/Projekt/team165/Implementierung/"

maxreps = 101

v0data = []
v1data = []
v2data = []

# %%
for i in range (1,maxreps):
    for j in range(0,3):
        version = j
        args = path + "gammaCorr", path + "/Input_Images/mandrill.ppm", "-o", path + "/Result_Images/test1.ppm", "-g", str(i), "-b", str(reps), "-v", str(version)
        popen = subprocess.Popen(args, stdout=subprocess.PIPE)
        popen.wait()
        output = popen.stdout.read()
        if(j==0):
            time = output[53:64]
            v0data.append(float(time))
        if(j==1):
            time = output[44:55]
            v1data.append(float(time))
        if(j==2):
            time = output[43:54]
            v2data.append(float(time))
        print("Version " + str(version) + " took " + str(time)[2:13] + " seconds for 100 Repetitions of an Image with a Gamma of " + str(i))
# Out:
# Version 0 took 0.072132691 seconds for an Image with a Gamma of 1
# Version 1 took 0.070101845 seconds for an Image with a Gamma of 1
# Version 2 took 0.178041289 seconds for an Image with a Gamma of 1
# Version 0 took 0.086613698 seconds for an Image with a Gamma of 2
# Version 1 took 0.101006904 seconds for an Image with a Gamma of 2
# Version 2 took 0.194937807 seconds for an Image with a Gamma of 2
# Version 0 took 0.073920120 seconds for an Image with a Gamma of 3
# Version 1 took 0.107627506 seconds for an Image with a Gamma of 3
# Version 2 took 0.166952766 seconds for an Image with a Gamma of 3
# Version 0 took 0.108845037 seconds for an Image with a Gamma of 4
# Version 1 took 0.117259276 seconds for an Image with a Gamma of 4
# Version 2 took 0.191446288 seconds for an Image with a Gamma of 4
# Version 0 took 0.119875531 seconds for an Image with a Gamma of 5
# Version 1 took 0.124429448 seconds for an Image with a Gamma of 5
# ...

# %%
d = {'Version 0': v0data, 'Version 1': v1data, 'Version 2': v2data}
df = pd.DataFrame(data=d)
ax = df.plot()
ax.set(xlabel = "Gamma", ylabel = "Time in seconds")
# Out:
# [Text(0.5, 0, 'Gamma'), Text(0, 0.5, 'Time in seconds')]

# %%
ax.get_figure().savefig('gammaplot.png')
